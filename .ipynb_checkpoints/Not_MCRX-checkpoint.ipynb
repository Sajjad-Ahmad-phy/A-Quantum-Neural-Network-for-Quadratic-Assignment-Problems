# %%
from qiskit import QuantumCircuit
from qiskit.circuit.library import MCXGate
qc = QuantumCircuit(4)

qc.append(MCXGate(3, ctrl_state='000'), [2, 1, 3, 0])
qc.draw('mpl')

# %%
from qiskit import QuantumCircuit,QuantumRegister
from qiskit.circuit.library.standard_gates import RXGate
from qiskit.circuit import Parameter
import matplotlib.pyplot as plt


qc=QuantumCircuit(4)
a=Parameter('a') # You can replace a with pi here 
CCCRX=RXGate(a).control(3, ctrl_state='000')

qc.append(CCCRX,[1, 3, 2, 0])

qc.draw('mpl')

# %%
from qiskit.circuit.library.standard_gates import RYGate
qc=QuantumCircuit(4)
a=Parameter('a')

ry = RYGate(a)
for qbit in range(4):
    qc.append(ry, [qbit])

qc.draw('mpl')

# %%
pip install sinkhorn_knopp
# Out:
# Collecting sinkhorn_knoppNote: you may need to restart the kernel to use updated packages.
#
#   Downloading sinkhorn_knopp-0.2-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: numpy>=1 in c:\users\lenovo\anaconda3\lib\site-packages (from sinkhorn_knopp) (1.26.0)
# Downloading sinkhorn_knopp-0.2-py3-none-any.whl (5.2 kB)
# Installing collected packages: sinkhorn_knopp
# Successfully installed sinkhorn_knopp-0.2
